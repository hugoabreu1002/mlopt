# %%
import sys
import numpy as np
from numpy.random import choice
import random
import matplotlib.pyplot as plt
import copy
from tqdm import tqdm
from IWO import IWO

# %% [markdown]
# # RASTRIGIN

# %%
def rastrigin(X, *args):
    return sum(list(map(lambda x: x**2 - 10*np.cos(2*np.pi*x) + 10, list(X))))

# %%
qt_iter = 1000
xticks = np.arange(1, qt_iter+1,1)

# %% [markdown]
# ## Global - Inercia Fixo

# %%
myIWO = IWO(dim=30, minx=-5, maxx=12, function=rastrigin)
myIWO = myIWO.search(weed_qtz_i=10, weed_qtz_f=30, MaxIt=qt_iter, print_at_every = 100, Smin=0, Smax=5,
                     Exponent = 2, sigma_initial = 0.5, sigma_final = 0.001)

print("IWO completed\n")
ras_hist_fit_t1 = myIWO.historic_best_error
fig= plt.figure(figsize=(10,6), dpi=300)
plt.plot(xticks, ras_hist_fit_t1, linewidth=2)
plt.xlabel("Iteração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()
# Out:
#  12%|█▏        | 115/1000 [00:00<00:08, 99.71it/s]
# ######## iteracao 100 ##########
# Best Point [-0.17073704  1.21767765 -1.20898396  0.20196182  0.97112459 -0.38699434
#   0.06419775  0.23822472  1.78800819  0.74067994  0.01073487 -0.72553771
#   1.19256157 -0.93074676  1.91313724  0.30567138  1.06601335 -0.02263154
#  -0.95601767  1.10556974 -1.92343769  0.00854356  0.89387997  0.87424786
#   0.89122208  0.64175685  1.88602221  0.98806191  0.55055303 -0.09724991], Best Cost: 188.65114939505253, Sigma: 0.4059995941887834, Weeds: 20
#  21%|██        | 208/1000 [00:02<00:14, 56.54it/s]
# ######## iteracao 200 ##########
# Best Point [ 4.71031686e-02 -4.69259838e-02  3.00859175e-01 -7.30774954e-01
#   9.06531989e-01  1.11315250e-01  1.89427622e+00  8.60717986e-01
#   9.92366650e-01  7.18985773e-01 -8.87893292e-01  1.12636268e+00
#  -9.30924112e-02  1.53516713e+00  3.75846319e-02  1.87359328e-03
#   1.08281993e+00  6.86036671e-01  3.04630242e+00  7.29074394e-01
#   9.77909928e-01  8.99804574e-01  9.45182855e-01  4.00731050e-02
#   1.07496022e+00  3.16890937e-01 -4.47593026e-01  1.20018128e+00
#  -2.33913769e-02  1.00584235e+00], Best Cost: 175.26036623512908, Sigma: 0.3209996793590388, Weeds: 25
#  31%|███       | 308/1000 [00:04<00:16, 41.60it/s]
# ######## iteracao 300 ##########
# Best Point [-0.02583173  0.99999276 -1.13017287  0.01030757  1.23035737 -0.37526861
#   0.02690602  0.77919624  1.7340714   0.81858052  0.04499182 -0.76332978
#   1.21474212 -0.88425878  1.90104046  0.26788835  1.08344177  0.02915677
#  -0.99794382  1.10468093 -1.95235736 -0.11575097  0.90643678  1.1027313
#   0.92437383  0.62566899  1.95660905  1.41616579  0.13986359 -0.05810236], Best Cost: 169.99954456100062, Sigma: 0.245999754509264, Weeds: 27
#  41%|████      | 409/1000 [00:06<00:10, 54.38it/s]
# ######## iteracao 400 ##########
# Best Point [ 1.58386257 -0.03850115 -0.43819631  0.81691022 -1.13928833  1.12834555
#   0.77615344  0.23663115 -1.13857737  0.19580637 -0.10524538  0.06486463
#  -0.03982007 -0.07338035  1.9979208   0.33351405  0.8923385   1.0162478
#  -1.08610193  0.04767094  0.8976609   1.01274699  0.92412525  1.72142027
#   0.14451473 -1.1007247   1.00710853  1.09561783  0.92119711  1.02624379], Best Cost: 151.8214343931076, Sigma: 0.18099981963945927, Weeds: 28
