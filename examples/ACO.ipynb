# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from scipy.stats import mode
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# relative parent import, just to be able to make examples in this subfolder...
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)
from mlopt.optimizers.ACO import ACO
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def rastrigin(X, *args):
    return sum(list(map(lambda x: x**2 - 10*np.cos(2*np.pi*x) + 10, list(X))))

# %%
X = [np.arange(-12,12,0.2), np.arange(-12,12,0.2)]

# %%
ACOsearch = ACO(1, 1, 0.5, 1)
ACOsearch.optimize(5, 5, X, rastrigin, verbose=True)
# Out:
# c:\Users\hugow\OneDrive - Fundação para Inovações Tecnológicas - FITec\Mestrado_PPGES_UPE\PROJETO\PVIA_research\mlopt\ACO.py:65: RuntimeWarning: divide by zero encountered in true_divide
#   return 1/np.zeros(self._Space.shape[0])
#  20%|██        | 1/5 [00:00<00:00, 55.70it/s]
# dimentions Ranges passed:  [array([-1.20000000e+01, -1.18000000e+01, -1.16000000e+01, -1.14000000e+01,
#        -1.12000000e+01, -1.10000000e+01, -1.08000000e+01, -1.06000000e+01,
#        -1.04000000e+01, -1.02000000e+01, -1.00000000e+01, -9.80000000e+00,
#        -9.60000000e+00, -9.40000000e+00, -9.20000000e+00, -9.00000000e+00,
#        -8.80000000e+00, -8.60000000e+00, -8.40000000e+00, -8.20000000e+00,
#        -8.00000000e+00, -7.80000000e+00, -7.60000000e+00, -7.40000000e+00,
#        -7.20000000e+00, -7.00000000e+00, -6.80000000e+00, -6.60000000e+00,
#        -6.40000000e+00, -6.20000000e+00, -6.00000000e+00, -5.80000000e+00,
#        -5.60000000e+00, -5.40000000e+00, -5.20000000e+00, -5.00000000e+00,
#        -4.80000000e+00, -4.60000000e+00, -4.40000000e+00, -4.20000000e+00,
#        -4.00000000e+00, -3.80000000e+00, -3.60000000e+00, -3.40000000e+00,
#        -3.20000000e+00, -3.00000000e+00, -2.80000000e+00, -2.60000000e+00,
#        -2.40000000e+00, -2.20000000e+00, -2.00000000e+00, -1.80000000e+00,
#        -1.60000000e+00, -1.40000000e+00, -1.20000000e+00, -1.00000000e+00,
#        -8.00000000e-01, -6.00000000e-01, -4.00000000e-01, -2.00000000e-01,
#        -4.26325641e-14,  2.00000000e-01,  4.00000000e-01,  6.00000000e-01,
#         8.00000000e-01,  1.00000000e+00,  1.20000000e+00,  1.40000000e+00,
#         1.60000000e+00,  1.80000000e+00,  2.00000000e+00,  2.20000000e+00,
#         2.40000000e+00,  2.60000000e+00,  2.80000000e+00,  3.00000000e+00,
#         3.20000000e+00,  3.40000000e+00,  3.60000000e+00,  3.80000000e+00,
#         4.00000000e+00,  4.20000000e+00,  4.40000000e+00,  4.60000000e+00,
#         4.80000000e+00,  5.00000000e+00,  5.20000000e+00,  5.40000000e+00,
#         5.60000000e+00,  5.80000000e+00,  6.00000000e+00,  6.20000000e+00,
#         6.40000000e+00,  6.60000000e+00,  6.80000000e+00,  7.00000000e+00,
#         7.20000000e+00,  7.40000000e+00,  7.60000000e+00,  7.80000000e+00,
#         8.00000000e+00,  8.20000000e+00,  8.40000000e+00,  8.60000000e+00,
#         8.80000000e+00,  9.00000000e+00,  9.20000000e+00,  9.40000000e+00,
#         9.60000000e+00,  9.80000000e+00,  1.00000000e+01,  1.02000000e+01,
#         1.04000000e+01,  1.06000000e+01,  1.08000000e+01,  1.10000000e+01,
#         1.12000000e+01,  1.14000000e+01,  1.16000000e+01,  1.18000000e+01]), array([-1.20000000e+01, -1.18000000e+01, -1.16000000e+01, -1.14000000e+01,
#        -1.12000000e+01, -1.10000000e+01, -1.08000000e+01, -1.06000000e+01,
#        -1.04000000e+01, -1.02000000e+01, -1.00000000e+01, -9.80000000e+00,
#        -9.60000000e+00, -9.40000000e+00, -9.20000000e+00, -9.00000000e+00,
#        -8.80000000e+00, -8.60000000e+00, -8.40000000e+00, -8.20000000e+00,
#        -8.00000000e+00, -7.80000000e+00, -7.60000000e+00, -7.40000000e+00,
#        -7.20000000e+00, -7.00000000e+00, -6.80000000e+00, -6.60000000e+00,
#        -6.40000000e+00, -6.20000000e+00, -6.00000000e+00, -5.80000000e+00,
#        -5.60000000e+00, -5.40000000e+00, -5.20000000e+00, -5.00000000e+00,
#        -4.80000000e+00, -4.60000000e+00, -4.40000000e+00, -4.20000000e+00,
#        -4.00000000e+00, -3.80000000e+00, -3.60000000e+00, -3.40000000e+00,
#        -3.20000000e+00, -3.00000000e+00, -2.80000000e+00, -2.60000000e+00,
#        -2.40000000e+00, -2.20000000e+00, -2.00000000e+00, -1.80000000e+00,
#        -1.60000000e+00, -1.40000000e+00, -1.20000000e+00, -1.00000000e+00,
#        -8.00000000e-01, -6.00000000e-01, -4.00000000e-01, -2.00000000e-01,
#        -4.26325641e-14,  2.00000000e-01,  4.00000000e-01,  6.00000000e-01,
#         8.00000000e-01,  1.00000000e+00,  1.20000000e+00,  1.40000000e+00,
#         1.60000000e+00,  1.80000000e+00,  2.00000000e+00,  2.20000000e+00,
#         2.40000000e+00,  2.60000000e+00,  2.80000000e+00,  3.00000000e+00,
#         3.20000000e+00,  3.40000000e+00,  3.60000000e+00,  3.80000000e+00,
#         4.00000000e+00,  4.20000000e+00,  4.40000000e+00,  4.60000000e+00,
#         4.80000000e+00,  5.00000000e+00,  5.20000000e+00,  5.40000000e+00,
#         5.60000000e+00,  5.80000000e+00,  6.00000000e+00,  6.20000000e+00,
#         6.40000000e+00,  6.60000000e+00,  6.80000000e+00,  7.00000000e+00,
#         7.20000000e+00,  7.40000000e+00,  7.60000000e+00,  7.80000000e+00,
#         8.00000000e+00,  8.20000000e+00,  8.40000000e+00,  8.60000000e+00,
#         8.80000000e+00,  9.00000000e+00,  9.20000000e+00,  9.40000000e+00,
#         9.60000000e+00,  9.80000000e+00,  1.00000000e+01,  1.02000000e+01,
#         1.04000000e+01,  1.06000000e+01,  1.08000000e+01,  1.10000000e+01,
#         1.12000000e+01,  1.14000000e+01,  1.16000000e+01,  1.18000000e+01])]
# Space Created:  [[-12 -12]
#  [-12 -11]
#  [-12 -11]
#  ...
#  [ 11  11]
#  [ 11  11]
#  [ 11  11]]
# number of Space Possibilities (rows):  14400
# Setting fitness for
# [4 0]
# fitness is
# 16.0
# Setting fitness for
# [ 4 10]
# fitness is
# 116.0
# Setting fitness for
# [-9  8]
# fitness is
# 145.0
# Setting fitness for
# [-7 -4]
# fitness is
# 65.0
# Setting fitness for
# [ -9 -10]
# fitness is
# 181.0
# Setting fitness for
# [-11  -2]
# fitness is
# 125.0
# Setting fitness for
# [ 6 -6]
# fitness is
# 72.0
# Setting fitness for
# [5 3]
# fitness is
# 34.0
# Setting fitness for
# [0 8]
# fitness is
# 64.0
# Setting fitness for
# [0 4]
# fitness is
# 16.0
# Dij:
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]]
# Tij:
# [[10.5]
#  [ 0.5]
#  [ 0.5]
#  ...
#  [ 0.5]
#  [ 0.5]
#  [ 0.5]]
# Pij:
# [[1.4572964e-03]
#  [6.9395064e-05]
#  [6.9395064e-05]
#  ...
#  [6.9395064e-05]
#  [6.9395064e-05]
#  [6.9395064e-05]]
# Ant 0 possibilities:
# [    0     1     2 ... 14397 14398 14399]
# Ant 0 move from 10141 to 1217
# Ant 1 possibilities:
# [    0     1     2 ... 14397 14398 14399]
# Ant 1 move from 1542 to 6364
# Ant 2 possibilities:
# [    0     1     2 ... 14397 14398 14399]
# Ant 2 move from 1327 to 8055
# Ant 3 possibilities:
# [    0     1     2 ... 14397 14398 14399]
# Ant 3 move from 11068 to 9335
# Ant 4 possibilities:
# [    0     1     2 ... 14397 14398 14399]
# Ant 4 move from 7425 to 14375
# Dij:
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]]
# Tij:
# [[10.5]
#  [ 0.5]
#  [ 0.5]
#  ...
#  [ 0.5]
#  [ 0.5]
#  [ 0.5]]
# Pij:
# [[1.4572964e-03]
#  [6.9395064e-05]
#  [6.9395064e-05]
#  ...
#  [6.9395064e-05]
#  [6.9395064e-05]
#  [6.9395064e-05]]
# Ants now - then
# [ 1217  6364  8055  9335 14375] - [10141  1542  1327 11068  7425]
# Setting fitness for
# [-10  -8]
# fitness is
# 164.0
# Setting fitness for
# [-10   1]
# fitness is
# 101.0
# Setting fitness for
# [ -1 -11]
# fitness is
# 122.0
# Setting fitness for
# [  0 -10]
# fitness is
# 100.0
# Setting fitness for
# [ 1 -9]
# fitness is
# 82.0
# Setting fitness for
# [  3 -10]
# fitness is
# 109.0
# Setting fitness for
# [3 6]
# fitness is
# 45.0
# Setting fitness for
# [3 0]
# fitness is
# 9.0
# Setting fitness for
# [11  6]
# fitness is
# 157.0
# Setting fitness for
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-59e8fc75eab4> in <module>
#       1 ACOsearch = ACO(1, 1, 0.5, 1)
# ----> 2 ACOsearch.optimize(5, 5, X, rastrigin, verbose=True)
#
# c:\Users\hugow\OneDrive - Fundação para Inovações Tecnológicas - FITec\Mestrado_PPGES_UPE\PROJETO\PVIA_research\mlopt\ACO.py in optimize(self, antNumber, antTours, dimentionsRanges, function, functionArgs, verbose)
#     202
#     203         for it in tqdm(range(self._antTours)):
# --> 204             self._Dij = self.updateDij(self._Dij, verbose)
#     205             if verbose:
#     206                 print("Dij: ")
#
# c:\Users\hugow\OneDrive - Fundação para Inovações Tecnológicas - FITec\Mestrado_PPGES_UPE\PROJETO\PVIA_research\mlopt\ACO.py in updateDij(self, Dij, verbose)
#     113                 if verbose:
#     114                     print("Setting fitness for")
# --> 115                     print(self._Space[j_index, :])
#     116
#     117                 Cj = self.fitnessFunction(self._Space[j_index, :], self._fitnessFunctionArgs)
#
# IndexError: index 14776 is out of bounds for axis 0 with size 14400

# %%
Pij = ACOsearch._Pij

# %%
Pij[~np.isnan(Pij)]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)
