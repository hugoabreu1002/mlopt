# %%
# %load_ext autoreload
# %autoreload 2

from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt
import numpy as np
import warnings
import itertools
import pickle
import datetime
import copy
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
granparentdir = os.path.dirname(os.path.dirname(currentdir))
sys.path.insert(0,parentdir)
sys.path.insert(0,granparentdir)

from TimeSeriesUtils import sarimax_ACO_search

warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Generating Fake Arrays

# %%
len_array = 100
number_exog_variables = 4

# array of exogenous variables
exog = np.random.rand(len_array, number_exog_variables)

# principal array, in each sarimax will performe
gen = np.random.rand(len_array,1)

# %%
plt.figure(figsize=(12,6))
plt.plot(exog,'--', linewidth=1, marker='o')
plt.plot(gen, linewidth=3.0, c='b')

# %% [markdown]
# # Stablish parameters to search and searching

# %%
# possibilities of parameters
p = d = q = [0, 1] 
sp = sd = sq = [0, 1]
s = [12,24] #seasonal order possibilites
# search Space, exog possibilities comes in the functions.
searchSpace = [p, d, q, sp, sd, sq, s]
# ACO parametrization
options_ACO={'antNumber':10, 'antTours':10, 'alpha':2, 'beta':2, 'rho':0.5, 'Q':2}

# Sarimax ACO search
y_sarimax_ACO = sarimax_ACO_search(endo_var=gen, exog_var_matrix=exog, searchSpace=copy.copy(searchSpace), options_ACO=options_ACO, verbose=True)
# Out:
# Setting fitness for
# [ 0  0  0  0  1  0 24  3]
# fitness is
# 79.78070118422866
# Setting fitness for
# [ 1  1  1  0  0  1 12  4]
# fitness is
# 44.64645458557808
# Setting fitness for
# [ 1  1  1  1  0  0 12  0]
# fitness is
# 41.03956289353795
# Setting fitness for
# [ 1  0  1  1  0  0 24  9]
# fitness is
# 54.3270493153082
# Setting fitness for
# [ 0  1  0  0  1  1 12  0]
# fitness is
# 87.21564271812547
# Setting fitness for
# [ 0  0  1  0  1  0 12 11]
# fitness is
# 80.6680018131598
# Setting fitness for
# [ 1  1  0  1  0  1 24  3]
# fitness is
# 67.38449193994921
# Setting fitness for
# [ 1  0  0  0  0  0 24  0]
# fitness is
# 71.95844901044956
# Setting fitness for
# [ 1  0  0  1  0  1 24  1]
# fitness is
# 60.695752489091866
# Setting fitness for
# [ 0  1  1  0  0  1 24 12]
# fitness is
# 44.899714823813014
# Setting fitness for
# [ 0  1  0  1  0  1 12 15]
# fitness is
# 90.74510888851553
# Setting fitness for
# [ 0  0  1  1  0  1 12 13]
# fitness is
# 53.38487285251824
# ...
