# %%
import sys
import numpy as np
from numpy.random import choice
import random
import matplotlib.pyplot as plt
import copy
from tqdm import tqdm
from PSO import PSO

# %% [markdown]
# # RASTRIGIN

# %%
def rastrigin(X, *args):
    return sum(list(map(lambda x: x**2 - 10*np.cos(2*np.pi*x) + 10, list(X))))

# %%
qt_iter = 1000
xticks = np.arange(1, qt_iter+1,1)

# %% [markdown]
# ## Global - Inercia Fixo

# %%
myPSO_Ras_1 = PSO(number_of_particles=30, dim=2, minx=-5, maxx=12, seed=1, function=rastrigin, functionArgs=[])
myPSO_Ras_1 = myPSO_Ras_1.Solver(max_epochs=qt_iter, w=0.8, c1=2.05, c2=2.05, topology='G')
print("\nPSO completed\n")
ras_hist_fit_t1 = myPSO_Ras_1.historic_best_error
fig= plt.figure(figsize=(10,6), dpi=300)
plt.plot(xticks, ras_hist_fit_t1, linewidth=2)
plt.xlabel("Iteração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()
# Out:
#  29%|██▉       | 293/1000 [00:00<00:00, 1487.69it/s]
# Epoch = 100 best error = 1.083
# Epoch = 200 best error = 0.843
# Epoch = 300 best error = 0.093
# Epoch = 400 best error = 0.053
#  74%|███████▍  | 745/1000 [00:00<00:00, 1498.10it/s]
# Epoch = 500 best error = 0.053
# Epoch = 600 best error = 0.053
# Epoch = 700 best error = 0.053
# Epoch = 800 best error = 0.053
# 100%|██████████| 1000/1000 [00:00<00:00, 1490.93it/s]
# Epoch = 900 best error = 0.049
#
# PSO completed

# %% [markdown]
# ## Global - Inercia Decaindo

# %%
myPSO_Ras_2 = PSO(number_of_particles=30, dim=2, minx=-5, maxx=12, seed=2, function=rastrigin, functionArgs=[])
myPSO_Ras_2 = myPSO_Ras_2.Solver(max_epochs=qt_iter, w=(0.8, 0.4), c1=2.05, c2=2.05, topology='G')
print("\nPSO completed\n")
ras_hist_fit_t2 = myPSO_Ras_2.historic_best_error
fig= plt.figure(figsize=(10,6), dpi=300)
plt.plot(xticks, ras_hist_fit_t2, linewidth=2)
plt.xlabel("Iteração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()
# Out:
#  23%|██▎       | 227/1000 [00:00<00:00, 1124.82it/s]
# Epoch = 100 best error = 0.248
# Epoch = 200 best error = 0.121
# Epoch = 300 best error = 0.067
#  56%|█████▌    | 556/1000 [00:00<00:00, 1101.19it/s]
# Epoch = 400 best error = 0.067
# Epoch = 500 best error = 0.004
# Epoch = 600 best error = 0.004
#  86%|████████▋ | 865/1000 [00:00<00:00, 1016.00it/s]
# Epoch = 700 best error = 0.000
# Epoch = 800 best error = 0.000
# 100%|██████████| 1000/1000 [00:00<00:00, 1061.69it/s]
# Epoch = 900 best error = 0.000
#
# PSO completed

# %% [markdown]
# ## Local - Inercia Fixo

# %%
myPSO_Ras_3 = PSO(number_of_particles=30, dim=2, minx=-5, maxx=12, seed=3, function=rastrigin, functionArgs=[])
myPSO_Ras_3 = myPSO_Ras_3.Solver(max_epochs=1000, w=0.8, c1=2.05, c2=2.05, topology='L')
print("\nPSO completed\n")
ras_hist_fit_t3 = myPSO_Ras_3.historic_best_error
fig= plt.figure(figsize=(10,6), dpi=300)
plt.plot(xticks, ras_hist_fit_t3, linewidth=2)
plt.xlabel("Iteração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()
# Out:
#  13%|█▎        | 127/1000 [00:00<00:05, 151.43it/s]
# Epoch = 100 best error = 2.216
#  22%|██▏       | 222/1000 [00:01<00:05, 153.69it/s]
# Epoch = 200 best error = 1.192
#  32%|███▏      | 320/1000 [00:02<00:04, 157.59it/s]
# Epoch = 300 best error = 0.963
#  42%|████▏     | 423/1000 [00:02<00:03, 165.75it/s]
# Epoch = 400 best error = 0.963
#  52%|█████▎    | 525/1000 [00:03<00:02, 161.28it/s]
# Epoch = 500 best error = 0.963
#  63%|██████▎   | 627/1000 [00:03<00:02, 161.34it/s]
# Epoch = 600 best error = 0.499
#  73%|███████▎  | 728/1000 [00:04<00:01, 155.20it/s]
# Epoch = 700 best error = 0.499
#  83%|████████▎ | 829/1000 [00:05<00:01, 159.74it/s]
# Epoch = 800 best error = 0.333
#  93%|█████████▎| 926/1000 [00:05<00:00, 155.25it/s]
# Epoch = 900 best error = 0.057
# 100%|██████████| 1000/1000 [00:06<00:00, 157.33it/s]
# PSO completed

# %% [markdown]
# ## Local - Inercia Decaindo

# %%
myPSO_Ras_4 = PSO(number_of_particles=30, dim=2, minx=-5, maxx=12, seed=4, function=rastrigin, functionArgs=[])
myPSO_Ras_4 = myPSO_Ras_4.Solver(max_epochs=1000, w=(0.8, 0.4), c1=2.05, c2=2.05, topology='L')
print("\nPSO completed\n")
ras_hist_fit_t4 = myPSO_Ras_4.historic_best_error
fig= plt.figure(figsize=(10,6), dpi=300)
plt.plot(xticks, ras_hist_fit_t4, linewidth=2)
plt.xlabel("Iteração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()
# Out:
#  13%|█▎        | 126/1000 [00:00<00:06, 126.22it/s]
# Epoch = 100 best error = 1.293
#  22%|██▏       | 224/1000 [00:01<00:05, 134.68it/s]
# Epoch = 200 best error = 1.175
#  32%|███▏      | 322/1000 [00:02<00:05, 120.06it/s]
# Epoch = 300 best error = 0.141
#  42%|████▏     | 422/1000 [00:03<00:04, 137.41it/s]
# Epoch = 400 best error = 0.141
#  53%|█████▎    | 526/1000 [00:03<00:03, 142.21it/s]
# Epoch = 500 best error = 0.052
#  62%|██████▏   | 617/1000 [00:04<00:02, 141.82it/s]
# Epoch = 600 best error = 0.052
#  72%|███████▏  | 723/1000 [00:05<00:01, 147.12it/s]
# Epoch = 700 best error = 0.030
#  83%|████████▎ | 829/1000 [00:06<00:01, 145.00it/s]
# Epoch = 800 best error = 0.030
#  92%|█████████▏| 920/1000 [00:06<00:00, 147.44it/s]
# Epoch = 900 best error = 0.002
# 100%|██████████| 1000/1000 [00:07<00:00, 139.13it/s]
# PSO completed

# %% [markdown]
# ## Focal - Inercia Fixo

# %%
myPSO_Ras_5 = PSO(number_of_particles=30, dim=2, minx=-5, maxx=12, seed=5, function=rastrigin, functionArgs=[])
myPSO_Ras_5 = myPSO_Ras_5.Solver(max_epochs=1000, w=0.8, c1=2.05, c2=2.05, topology='F')
print("\nPSO completed\n")
ras_hist_fit_t5 = myPSO_Ras_5.historic_best_error
fig= plt.figure(figsize=(10,6), dpi=300)
plt.plot(xticks, ras_hist_fit_t5, linewidth=2)
plt.xlabel("Iteração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()
# Out:
#  46%|████▌     | 462/1000 [00:00<00:00, 1507.66it/s]
# Epoch = 100 best error = 0.268
# Epoch = 200 best error = 0.268
# Epoch = 300 best error = 0.268
# Epoch = 400 best error = 0.268
#  93%|█████████▎| 931/1000 [00:00<00:00, 1535.63it/s]
# Epoch = 500 best error = 0.268
# Epoch = 600 best error = 0.268
# Epoch = 700 best error = 0.268
# Epoch = 800 best error = 0.268
# Epoch = 900 best error = 0.268
# 100%|██████████| 1000/1000 [00:00<00:00, 1538.57it/s]
# PSO completed

# %% [markdown]
# ## Focal - Inercia Decaindo

# %%
myPSO_Ras_6 = PSO(number_of_particles=30, dim=2, minx=-5, maxx=12, seed=6, function=rastrigin, functionArgs=[])
myPSO_Ras_6 = myPSO_Ras_6.Solver(max_epochs=1000, w=(0.8, 0.4), c1=2.05, c2=2.05, topology='F')
print("\nPSO completed\n")
ras_hist_fit_t6 = myPSO_Ras_6.historic_best_error
fig= plt.figure(figsize=(10,6), dpi=300)
plt.plot(xticks, ras_hist_fit_t6, linewidth=2)
plt.xlabel("Iteração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()
# Out:
#  36%|███▋      | 365/1000 [00:00<00:00, 1201.83it/s]
# Epoch = 100 best error = 1.313
# Epoch = 200 best error = 1.103
# Epoch = 300 best error = 0.220
#  73%|███████▎  | 727/1000 [00:00<00:00, 1197.73it/s]
# Epoch = 400 best error = 0.216
# Epoch = 500 best error = 0.216
# Epoch = 600 best error = 0.094
# Epoch = 700 best error = 0.090
# 100%|██████████| 1000/1000 [00:00<00:00, 1196.38it/s]
# Epoch = 800 best error = 0.023
# Epoch = 900 best error = 0.001
#
# PSO completed

# %% [markdown]
# ## Um grafico

# %%
fig= plt.figure(figsize=(12,6), dpi=300)

plt.plot(xticks[:250], ras_hist_fit_t1[:250], c='g', linewidth=2, label="Global - w Fixo")
plt.plot(xticks[:250], ras_hist_fit_t2[:250], c='b', linewidth=2, label="Global - w decaindo")
plt.plot(xticks[:250], ras_hist_fit_t3[:250], c='r', linewidth=2, label="Local - w Fixo")
plt.plot(xticks[:250], ras_hist_fit_t4[:250], c='y', linewidth=2, label="Local - w decaindo")
plt.plot(xticks[:250], ras_hist_fit_t5[:250], c='tab:brown', linewidth=2, label="Focal - w Fixo")
plt.plot(xticks[:250], ras_hist_fit_t6[:250], c='tab:gray', linewidth=2, label="Focal - w decaindo")

plt.legend(fontsize=14)
plt.xlabel("Geração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()

# %%
fig= plt.figure(figsize=(12,6), dpi=300)

plt.plot(xticks[250:500], ras_hist_fit_t1[250:500], c='g', linewidth=2, label="Global - w Fixo")
plt.plot(xticks[250:500], ras_hist_fit_t2[250:500], c='b', linewidth=2, label="Global - w decaindo")
plt.plot(xticks[250:500], ras_hist_fit_t3[250:500], c='r', linewidth=2, label="Local - w Fixo")
plt.plot(xticks[250:500], ras_hist_fit_t4[250:500], c='y', linewidth=2, label="Local - w decaindo")
plt.plot(xticks[250:500], ras_hist_fit_t5[250:500], c='tab:brown', linewidth=2, label="Focal - w Fixo")
plt.plot(xticks[250:500], ras_hist_fit_t6[250:500], c='tab:gray', linewidth=2, label="Focal - w decaindo")

plt.legend(fontsize=14)
plt.xlabel("Geração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()

# %%
fig= plt.figure(figsize=(12,6), dpi=300)

plt.plot(xticks[500:750], ras_hist_fit_t1[500:750], c='g', linewidth=2, label="Global - w Fixo")
plt.plot(xticks[500:750], ras_hist_fit_t2[500:750], c='b', linewidth=2, label="Global - w decaindo")
plt.plot(xticks[500:750], ras_hist_fit_t3[500:750], c='r', linewidth=2, label="Local - w Fixo")
plt.plot(xticks[500:750], ras_hist_fit_t4[500:750], c='y', linewidth=2, label="Local - w decaindo")
plt.plot(xticks[500:750], ras_hist_fit_t5[500:750], c='tab:brown', linewidth=2, label="Focal - w Fixo")
plt.plot(xticks[500:750], ras_hist_fit_t6[500:750], c='tab:gray', linewidth=2, label="Focal - w decaindo")

plt.legend(fontsize=14)
plt.xlabel("Geração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()

# %%
fig= plt.figure(figsize=(12,6), dpi=300)

plt.plot(xticks[750:], ras_hist_fit_t1[750:], c='g', linewidth=2, label="Global - w Fixo")
plt.plot(xticks[750:], ras_hist_fit_t2[750:], c='b', linewidth=2, label="Global - w decaindo")
plt.plot(xticks[750:], ras_hist_fit_t3[750:], c='r', linewidth=2, label="Local - w Fixo")
plt.plot(xticks[750:], ras_hist_fit_t4[750:], c='y', linewidth=2, label="Local - w decaindo")
plt.plot(xticks[750:], ras_hist_fit_t5[750:], c='tab:brown', linewidth=2, label="Focal - w Fixo")
plt.plot(xticks[750:], ras_hist_fit_t6[750:], c='tab:gray', linewidth=2, label="Focal - w decaindo")

plt.legend(fontsize=14)
plt.xlabel("Geração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()

# %% [markdown]
# # ROSENBROCK

# %%
def rosenbrock(X, *args):
    result = 0
    for i in range(len(X)-1):
        result += 100*(X[i+1]-X[i]**2)**2 + (X[i]-1)**2
    return result

# %% [markdown]
# ## Global - Inercia Fixo

# %%
myPSO_Ros_1 = PSO(number_of_particles=30, dim=2, minx=-5, maxx=10, seed=1, function=rosenbrock, functionArgs=[])
myPSO_Ros_1 = myPSO_Ros_1.Solver(max_epochs=qt_iter, w=0.8, c1=2.05, c2=2.05, topology='G')
print("\nPSO completed\n")
ros_hist_fit_t1 = myPSO_Ros_1.historic_best_error
fig= plt.figure(figsize=(10,6), dpi=300)
plt.plot(xticks, ros_hist_fit_t1, linewidth=2)
plt.xlabel("Iteração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()
# Out:
#  65%|██████▌   | 653/1000 [00:00<00:00, 3299.83it/s]
# Epoch = 100 best error = 0.159
# Epoch = 200 best error = 0.066
# Epoch = 300 best error = 0.066
# Epoch = 400 best error = 0.066
# Epoch = 500 best error = 0.061
# Epoch = 600 best error = 0.047
# Epoch = 700 best error = 0.037
# Epoch = 800 best error = 0.020
# 100%|██████████| 1000/1000 [00:00<00:00, 3113.76it/s]
# Epoch = 900 best error = 0.002
#
# PSO completed

# %% [markdown]
# ## Global - Inercia Decaindo

# %%
myPSO_Ros_2 = PSO(number_of_particles=30, dim=2, minx=-5, maxx=10, seed=2, function=rosenbrock, functionArgs=[])
myPSO_Ros_2 = myPSO_Ros_2.Solver(max_epochs=qt_iter, w=(0.8, 0.4), c1=2.05, c2=2.05, topology='G')
print("\nPSO completed\n")
ros_hist_fit_t2 = myPSO_Ros_2.historic_best_error
fig= plt.figure(figsize=(10,6), dpi=300)
plt.plot(xticks, ros_hist_fit_t2, linewidth=2)
plt.xlabel("Iteração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()
# Out:
#  40%|███▉      | 399/1000 [00:00<00:00, 1972.62it/s]
# Epoch = 100 best error = 0.048
# Epoch = 200 best error = 0.048
# Epoch = 300 best error = 0.010
# Epoch = 400 best error = 0.009
#  96%|█████████▌| 962/1000 [00:00<00:00, 1904.09it/s]
# Epoch = 500 best error = 0.009
# Epoch = 600 best error = 0.001
# Epoch = 700 best error = 0.001
# Epoch = 800 best error = 0.000
# Epoch = 900 best error = 0.000
# 100%|██████████| 1000/1000 [00:00<00:00, 1906.58it/s]
# PSO completed

# %% [markdown]
# ## Local - Inercia Fixo

# %%
myPSO_Ros_3 = PSO(number_of_particles=30, dim=2, minx=-5, maxx=10, seed=3, function=rosenbrock, functionArgs=[])
myPSO_Ros_3 = myPSO_Ros_3.Solver(max_epochs=1000, w=0.8, c1=2.05, c2=2.05, topology='L')
print("\nPSO completed\n")
ros_hist_fit_t3 = myPSO_Ros_3.historic_best_error
fig= plt.figure(figsize=(10,6), dpi=300)
plt.plot(xticks, ros_hist_fit_t3, linewidth=2)
plt.xlabel("Iteração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()
# Out:
#  13%|█▎        | 132/1000 [00:00<00:04, 215.10it/s]
# Epoch = 100 best error = 0.110
#  24%|██▍       | 241/1000 [00:01<00:03, 211.70it/s]
# Epoch = 200 best error = 0.071
#  33%|███▎      | 329/1000 [00:01<00:03, 215.43it/s]
# Epoch = 300 best error = 0.003
#  43%|████▎     | 434/1000 [00:02<00:02, 197.27it/s]
# Epoch = 400 best error = 0.003
#  54%|█████▎    | 536/1000 [00:02<00:02, 196.93it/s]
# Epoch = 500 best error = 0.003
#  64%|██████▍   | 639/1000 [00:03<00:01, 196.40it/s]
# Epoch = 600 best error = 0.003
#  72%|███████▏  | 717/1000 [00:03<00:01, 179.84it/s]
# Epoch = 700 best error = 0.001
#  83%|████████▎ | 829/1000 [00:04<00:01, 169.73it/s]
# Epoch = 800 best error = 0.001
#  93%|█████████▎| 933/1000 [00:04<00:00, 170.21it/s]
# Epoch = 900 best error = 0.001
# 100%|██████████| 1000/1000 [00:05<00:00, 191.45it/s]
# PSO completed

# %% [markdown]
# ## Local - Inercia Decaindo

# %%
myPSO_Ros_4 = PSO(number_of_particles=30, dim=2, minx=-5, maxx=10, seed=4, function=rosenbrock, functionArgs=[])
myPSO_Ros_4 = myPSO_Ros_4.Solver(max_epochs=1000, w=(0.8, 0.4), c1=2.05, c2=2.05, topology='L')
print("\nPSO completed\n")
ros_hist_fit_t4 = myPSO_Ros_4.historic_best_error
fig= plt.figure(figsize=(10,6), dpi=300)
plt.plot(xticks, ros_hist_fit_t4, linewidth=2)
plt.xlabel("Iteração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()
# Out:
#  12%|█▏        | 124/1000 [00:01<00:07, 116.43it/s]
# Epoch = 100 best error = 0.064
#  22%|██▏       | 222/1000 [00:01<00:06, 118.67it/s]
# Epoch = 200 best error = 0.036
#  32%|███▏      | 321/1000 [00:02<00:05, 117.13it/s]
# Epoch = 300 best error = 0.004
#  42%|████▏     | 418/1000 [00:03<00:05, 113.61it/s]
# Epoch = 400 best error = 0.004
#  52%|█████▏    | 518/1000 [00:04<00:04, 119.69it/s]
# Epoch = 500 best error = 0.004
#  62%|██████▏   | 617/1000 [00:05<00:03, 118.38it/s]
# Epoch = 600 best error = 0.004
#  72%|███████▏  | 715/1000 [00:06<00:02, 119.44it/s]
# Epoch = 700 best error = 0.004
#  81%|████████  | 811/1000 [00:06<00:01, 108.45it/s]
# Epoch = 800 best error = 0.004
#  92%|█████████▏| 918/1000 [00:07<00:00, 107.69it/s]
# Epoch = 900 best error = 0.004
# 100%|██████████| 1000/1000 [00:08<00:00, 115.07it/s]
# PSO completed

# %% [markdown]
# ## Focal - Inercia Fixo

# %%
myPSO_Ros_5 = PSO(number_of_particles=30, dim=2, minx=-5, maxx=10, seed=5, function=rosenbrock, functionArgs=[])
myPSO_Ros_5 = myPSO_Ros_5.Solver(max_epochs=1000, w=0.8, c1=2.05, c2=2.05, topology='F')
print("\nPSO completed\n")
ros_hist_fit_t5 = myPSO_Ros_5.historic_best_error
fig= plt.figure(figsize=(10,6), dpi=300)
plt.plot(xticks, ros_hist_fit_t5, linewidth=2)
plt.xlabel("Iteração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()
# Out:
#  60%|█████▉    | 597/1000 [00:00<00:00, 1877.81it/s]
# Epoch = 100 best error = 0.043
# Epoch = 200 best error = 0.043
# Epoch = 300 best error = 0.043
# Epoch = 400 best error = 0.043
# Epoch = 500 best error = 0.043
# 100%|██████████| 1000/1000 [00:00<00:00, 2056.24it/s]
# Epoch = 600 best error = 0.013
# Epoch = 700 best error = 0.013
# Epoch = 800 best error = 0.003
# Epoch = 900 best error = 0.003
#
# PSO completed

# %% [markdown]
# ## Focal - Inercia Decaindo

# %%
myPSO_Ros_6 = PSO(number_of_particles=30, dim=2, minx=-5, maxx=10, seed=6, function=rosenbrock, functionArgs=[])
myPSO_Ros_6 = myPSO_Ros_6.Solver(max_epochs=1000, w=(0.8, 0.4), c1=2.05, c2=2.05, topology='F')
print("\nPSO completed\n")
ros_hist_fit_t6 = myPSO_Ros_6.historic_best_error
fig= plt.figure(figsize=(10,6), dpi=300)
plt.plot(xticks, ros_hist_fit_t6, linewidth=2)
plt.xlabel("Iteração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()
# Out:
#  40%|████      | 402/1000 [00:00<00:00, 1346.65it/s]
# Epoch = 100 best error = 0.006
# Epoch = 200 best error = 0.006
# Epoch = 300 best error = 0.006
# Epoch = 400 best error = 0.006
#  94%|█████████▎| 935/1000 [00:00<00:00, 1322.27it/s]
# Epoch = 500 best error = 0.006
# Epoch = 600 best error = 0.006
# Epoch = 700 best error = 0.006
# Epoch = 800 best error = 0.006
# Epoch = 900 best error = 0.006
# 100%|██████████| 1000/1000 [00:00<00:00, 1322.97it/s]
# PSO completed

# %% [markdown]
# ## Um grafico

# %%
fig= plt.figure(figsize=(10,6), dpi=300)

plt.plot(xticks[:250], ros_hist_fit_t1[:250], c='g', linewidth=2, label="Global - w Fixo")
plt.plot(xticks[:250], ros_hist_fit_t2[:250], c='b', linewidth=2, label="Global - w decaindo")
plt.plot(xticks[:250], ros_hist_fit_t3[:250], c='r', linewidth=2, label="Local - w Fixo")
plt.plot(xticks[:250], ros_hist_fit_t4[:250], c='y', linewidth=2, label="Local - w decaindo")
plt.plot(xticks[:250], ros_hist_fit_t5[:250], c='tab:brown', linewidth=2, label="Focal - w Fixo")
plt.plot(xticks[:250], ros_hist_fit_t6[:250], c='tab:gray', linewidth=2, label="Focal - w decaindo")

plt.ylim([0,2])
plt.legend(fontsize=14)
plt.xlabel("Geração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()

# %%
fig= plt.figure(figsize=(10,6), dpi=300)

plt.plot(xticks[250:500], ros_hist_fit_t1[250:500], c='g', linewidth=2, label="Global - w Fixo")
plt.plot(xticks[250:500], ros_hist_fit_t2[250:500], c='b', linewidth=2, label="Global - w decaindo")
plt.plot(xticks[250:500], ros_hist_fit_t3[250:500], c='r', linewidth=2, label="Local - w Fixo")
plt.plot(xticks[250:500], ros_hist_fit_t4[250:500], c='y', linewidth=2, label="Local - w decaindo")
plt.plot(xticks[250:500], ros_hist_fit_t5[250:500], c='tab:brown', linewidth=2, label="Focal - w Fixo")
plt.plot(xticks[250:500], ros_hist_fit_t6[250:500], c='tab:gray', linewidth=2, label="Focal - w decaindo")

plt.legend(fontsize=14)
plt.xlabel("Geração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()

# %%
fig= plt.figure(figsize=(10,6), dpi=300)

plt.plot(xticks[500:750], ros_hist_fit_t1[500:750], c='g', linewidth=2, label="Global - w Fixo")
plt.plot(xticks[500:750], ros_hist_fit_t2[500:750], c='b', linewidth=2, label="Global - w decaindo")
plt.plot(xticks[500:750], ros_hist_fit_t3[500:750], c='r', linewidth=2, label="Local - w Fixo")
plt.plot(xticks[500:750], ros_hist_fit_t4[500:750], c='y', linewidth=2, label="Local - w decaindo")
plt.plot(xticks[500:750], ros_hist_fit_t5[500:750], c='tab:brown', linewidth=2, label="Focal - w Fixo")
plt.plot(xticks[500:750], ros_hist_fit_t6[500:750], c='tab:gray', linewidth=2, label="Focal - w decaindo")

plt.legend(fontsize=14)
plt.xlabel("Geração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()

# %%
fig= plt.figure(figsize=(10,6), dpi=300)

plt.plot(xticks[750:], ros_hist_fit_t1[750:], c='g', linewidth=2, label="Global - w Fixo")
plt.plot(xticks[750:], ros_hist_fit_t2[750:], c='b', linewidth=2, label="Global - w decaindo")
plt.plot(xticks[750:], ros_hist_fit_t3[750:], c='r', linewidth=2, label="Local - w Fixo")
plt.plot(xticks[750:], ros_hist_fit_t4[750:], c='y', linewidth=2, label="Local - w decaindo")
plt.plot(xticks[750:], ros_hist_fit_t5[750:], c='tab:brown', linewidth=2, label="Focal - w Fixo")
plt.plot(xticks[750:], ros_hist_fit_t6[750:], c='tab:gray', linewidth=2, label="Focal - w decaindo")

plt.legend(fontsize=14)
plt.xlabel("Geração", fontsize=14)
plt.ylabel("Valor objetivo", fontsize=14)
plt.grid()
